# %% [markdown]
# # Churn Predictor
#
# For practice with AWS SageMaker.

# %% [markdown]
# ## SETUP

# %%
# session = Session()
# role = get_execution_role()

# print(f"Using role: {role}")
# print(f"Default bucket: {session.default_bucket()}")

# %% [markdown]
# ## DATA  COLLECTION
